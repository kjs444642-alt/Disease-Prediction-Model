# %% [markdown]
# <a href="https://colab.research.google.com/github/kjs444642-alt/diabetes-Prediction-Model/blob/main/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8_%EC%A0%9C%EC%95%88%EC%84%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 프로젝트 제안서
#
# 1. 프로젝트 개요
#
# * 프로젝트 이름: 당뇨병 예측 모델
# * 작성자: 김준서
# * 작성일: 4/9
#
# 2. 배경 및 필요성
#
# * 최근 생활 습관 변화로 인해 당뇨병 환자가 증가하고 있으며, 조기 진단이 어려워 다양한 합병증으로 이어질 위험이 크다. 기존 진단 방식은 병원 검사에 의존하여 사전 예방에 한계가 있다. 이에 따라 개인의 건강 데이터를 활용하여 당뇨병 발생 위험을 사전에 예측할 필요성이 증가하고 있다. 본 프로젝트는 머신러닝을 활용하여 당뇨병 발병 가능성을 예측하고, 데이터 기반의 예방적 관리 방안을 제시하고자 한다.
#
# 3. 데이터셋
#
# * 본 프로젝트에서는 Kaggle에서 제공하는 당뇨병 데이터셋(Pima Indians Diabetes Dataset)을 사용한다. 해당 데이터는 혈당, 혈압, BMI, 나이 등 환자의 건강 정보를 포함하고 있으며, 이를 기반으로 당뇨병 발병 여부를 예측하는 이진 분류 문제로 구성되어 있다.[링크텍스트](https://www.kaggle.com/code/paultimothymooney/predict-diabetes-from-medical-records/input)
#
# * ![화면 캡쳐 2026-04-09 171726](https://drive.google.com/uc?export=view&id=1SOnBC2Q4wqAmi3m6iBKNwzDDduaHsB1e)
#
# 4. 목표
#
# * 본 프로젝트는 개인의 건강 정보를 바탕으로 당뇨병 발병 가능성을 사전에 예측하는 것을 목표로 한다. 이를 통해 당뇨병을 조기에 인지하고 예방 및 관리에 도움을 줄 수 있는 방안을 제시하고자 한다.
#
# 5. 주요 기능 및 특징
#
# * 개인의 건강 정보를 기반으로 당뇨병 발병 가능성을 예측
# * 주요 건강 지표와 당뇨병 간의 관계를 분석하여 위험 요인 도출
# * 분석 결과를 통해 당뇨병의 예방 및 관리에 활용 가능한 정보 제공
# * 직관적인 결과 제시를 통해 누구나 이해할 수 있는 형태로 제공
#
# 6. 기대 효과
#
# * 당뇨병을 사전에 예측하여 조기 발견 및 예방에 도움을 줄 수 있으며, 건강 관리에 유용한 정보를 제공할 것으로 기대된다.
#
# 7. 일정 계획
#
# ### 1주차
#
# * 데이터셋 선정 및 수집
# * 데이터 구조 및 변수 이해
# * 기초적인 데이터 탐색 진행
#
# ### 2주차
#
# * 데이터 전처리 및 정제
# * 주요 변수 분석 및 시각화 수행
# * 당뇨병과 관련된 주요 요인 도출
#
# ### 3주차
#
# * 예측 모델 구축
# * 모델 성능 평가 및 개선
# * 위험도 등급 기준 설정
#
# ### 4주차
#
# * 위험도 등급별 결과 분석
# * 최종 결과 정리 및 시각화
# * 보고서 작성 및 발표 자료 준비
#
# 8. 결론
#
# 본 프로젝트는 건강 데이터를 기반으로 당뇨병 발병 가능성을 예측하고, 이를 위험도 등급으로 구분하여 보다 직관적인 결과를 제공하는 것을 목표로 한다. 이를 통해 당뇨병의 조기 인지와 예방에 기여하고, 데이터 기반 건강 관리의 활용 가능성을 확인하고자 한다.
#
# 9. 기존 프로젝트의 문제점 개선
#
# 기존의 당뇨병 예측 모델은 결과를 단순히 ‘발병 여부(0/1)’로만 제시하여, 개인의 위험 수준을 구체적으로 파악하기 어렵다는 한계가 있다. 이러한 방식은 실제 건강 관리나 예방 측면에서 활용도가 제한적이다.
#
# 이에 본 프로젝트에서는 예측 결과를 확률 기반의 위험도 등급(저위험, 중위험, 고위험)으로 구분하여 제시함으로써, 보다 직관적이고 실질적인 건강 상태 평가가 가능하도록 개선하였다. 이를 통해 개인이 자신의 상태를 보다 쉽게 이해하고, 예방 및 관리에 활용할 수 있도록 한다.
#
# 10. 실제 환경 적용 및 개선 방안
#
# 실제 환경에서는 개인의 건강 데이터에 결측값이 존재하거나 측정값에 편차가 발생하는 등 데이터 품질이 일정하지 않을 수 있다. 이러한 문제는 모델의 예측 정확도에 영향을 줄 수 있다.
#
# 이를 반영하기 위해 결측값 처리 및 데이터 정규화 과정을 적용하고, 데이터 불균형을 완화하는 기법을 활용하여 다양한 데이터 조건에서도 안정적으로 예측이 가능하도록 한다. 또한 예측 확률을 기반으로 위험도를 구간화하여 일관된 기준으로 결과를 제공하도록 한다.
#
# 11. 성능 개선 방안
#
# 모델의 예측 성능을 향상시키기 위해 데이터 전처리 과정을 통해 결측값을 보완하고, 데이터 정규화를 적용하여 학습 안정성을 높인다. 또한 데이터 불균형 문제를 완화하기 위한 기법을 적용하여 특정 클래스에 치우치지 않도록 한다.
#
# 추가적으로 모델의 하이퍼파라미터를 조정하여 최적의 성능을 도출하고, 변수 중요도 분석을 통해 불필요한 변수를 제거함으로써 예측 정확도를 향상시킨다.
